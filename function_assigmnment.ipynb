# %% [markdown]
# <a href="https://colab.research.google.com/github/mkkcfsofsda/Pythonbasic/blob/main/function_assigmnment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. What is the difference between a function and a method in Python?
#
# Function is an independend reusable blok of code to perform an specific task while method is a function associated with a module or class.
#
# #2. Explain the concept of function arguments and parameters in Python.
#
# In case of function these are the value we send while calling a function. In the function definition the varible which are defined to be passed are called argument while the value we put at the time of calling function termed as patrameter.
#
# #3. What are the different ways to define and call a function in Python?
#
# In Python, functions can be defined and called in various ways depending on the requirements. fuction without an argument, function with one or more positional argument, functionn with keyword and default argument and last but not the least fuction with variavle length arguments. Fuction can also be defined anonymously that is lambda funtion.
#
# #4. What is the purpose of the `return` statement in a Python function?
#
# Return statement pass a defined value to the caller after execution.
#
# #5. What is the purpose of the `return` statement in a Python function?
#
# Iterators allow to traverse from one member to another sequentially, while iterable are varible type or container which have members, that can be iterated.
#
# #6.  Explain the concept of generators in Python and how they are defined.
#
# Generators are specific type of functions with lazy execution it produce value on demand, instead of returning they yield the value. They are defined as normal function with def keyword with yield statement is used in place of return.
#
# #7.  What are the advantages of using generators over regular functions?
#
# Generator function produce value on demannd with next statement after this its execution is paused. Thus requres less memory and resources.
#
# #8. What is a lambda function in Python and when is it typically used?
#
# A lambda function in Python is a small, anonymous function defined using the lambda keyword. Lambda functions are concise and consist of a single expression. Lambda functions are typically used for short, immediate operations
# as Arguments to Higher-Order Functions like map(), reduce(), and filter().
#
# #9.  Explain the purpose and usage of the `map()` function in Python.
#
# Map function in python is used to do operation on one or more iterable of same length, it performs same operation on each menber of the given iterables. It returns a map object, which is an iterator, containing the results of applying the function to each item.
#
# #10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# The map(), reduce(), and filter() functions in Python are higher-order functions used in functional programming to process and transform data. Here's a concise explanation of their differences:
#
#  map()
#
#  Applies a given function to each item in an iterable (e.g., list, tuple) and returns a new iterable with the transformed items.
#
#  filter()
#
# Filters elements from an iterable based on a condition defined by a function, returning only the elements that satisfy the condition.
#
#  reduce()
#
# Applies a function cumulatively to the items in an iterable, reducing it to a single value. It is part of the functools module. It requires and work on two arguments.
#
# #11.  Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
#
# sum = reduce( lambda x, y: x+y, [47, 11, 42, 13])
#
# ![IMG_20250828_090717.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![IMG_20250828_090717.jpg]()

# %% [markdown]
# # Practical Question

# %%
#1.  Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

def sum_even_numbers(numbers):
    sum_even = 0
    for num in numbers:
        if num % 2 == 0:
            sum_even += num
    return sum_even

ls = [ 2, 3, 5, 6, 2, 8, 9, 12, 23]
result = sum_even_numbers(ls)
print(result)
# Out:
# 30

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string.

def reverse_string(string):
    reversed_string = string[::-1]

    return reversed_string

string = "Hello World"
result = reverse_string(string)
print(result)
# Out:
# dlroW olleH

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

ls1 = [2, 3, 4, 5, 6]
sql = [s for s in map(lambda x : x*x, ls1)]
print(sql)
# Out:
# [4, 9, 16, 25, 36]

# %%
#4. Write a Python function that checks if a given number is prime or not from 1 to 200.

num = int(input("Enter a number: "))
if num > 1:
    for i in range(2, num ):
        if (num % i) == 0:
            print(num, "is not a prime number")
            break
    else:
        print(num, "is a prime number")
# Out:
# Enter a number: 6
# 6 is not a prime number

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

# %%
#6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

def power_of_two(exponent):
    for i in range(exponent + 1):
        yield 2 ** i

exponent = 5
x = power_of_two(exponent + 1)
for i in range(5):
    print(next(x))
# Out:
# 1
# 2
# 4
# 8
# 16

# %%
#7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

l1 = [(1, 2, 3), (5, 3, 8, 6), (4, 1, 5, 8)]
l2 = sorted(l1, key = lambda x : x[1])
print(l2)
# Out:
# [(4, 1, 5, 8), (1, 2, 3), (5, 3, 8, 6)]

# %%
#9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

celsius_temp = [-40, 0, 6, 8, 32, 80, 100]
fohrenheit_temp = list(map(lambda x : (x * 1.8) + 32, celsius_temp))
print(fohrenheit_temp)
# Out:
# [-40.0, 32.0, 42.8, 46.4, 89.6, 176.0, 212.0]

# %%
#10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

s = 'This my first string'
l1 = list(filter(lambda x : x not in ['a', 'e', 'i', 'o', 'u'], s))
s1 = ''.join(l1)
print(s)
print(s1)
# Out:
# This my first string
# Ths my frst strng

# %%
# Questions 11

product = [[3458, 'Learning Python, Mark Lutz', 4, 40.95], [98762, 'Programing Python, Mark Lutz', 5, 56.80], [77226, 'Head First Python, Paul Barry', 3, 32.95], [88112, 'Einfuhrung in Python3, Bernd Klein', 3, 24.99]]
order = tuple( y[0] for y  in map(lambda x : x, product))
value = tuple( map(lambda x : x[2] * x[3] if (x[2] * x[3] > 100 ) else x[2] * x[3] +10, product))
value_list = [order, value]
print(value_list)
# Out:
# [(3458, 98762, 77226, 88112), (163.8, 284.0, 108.85000000000001, 84.97)]
