# %% [markdown]
# # Theory Questions ,

# %% [markdown]
# # 1 What is python and why is popular?
# - Python is a programming language that is easy to understand and write, making it a popular choice among developers and programmers.
# It is compatible with various programming paradigms, such as procedural, object-oriented, and functional programming.
# Python has a large and active community of developers, an extensive standard library, and third-party packages for various domains.
#
# # 2 What is an interpreter in Python?
# -  Python interpreter executes one statement at a time, it converts statement to machine readable codes.
#
# # 3 What are pre-defined keywords in Python?
# - Predefined keywords in python are those words which have special meaning and reserved . They can not be used as identifier.
#
# # 4 Can keywords be used as variable names?
# - Resrved words can not be used as variable name.
#
# # 5 What is mutability in Python?
# - Mutable objects, such as lists and dictionaries, can be modified after creation, while immutable objects, such as tuples and strings, cannot.
#
# # 6 Why are lists mutable, but tuples are immutable?
# - Because  lists  can be modified after creation means it value can be changed, while value of tuple cannot be changed once assigned.
#
# # 7 What is the difference between “==” and “is” operators in Python?
#
# - The "is" operator in Python is used to compare the identity of two objects. This means it checks whether two variables point to the same object in memory, rather than comparing their values. while "==" opretor compares values of the objects.
#
# # 8 What are logical operators in Python?
# - Logical operators in Python are used to perform logical operations on boolean values (True or False). They are commonly used in conditional statements and expressions to combine or modify conditions. Python provides three logical operators:
# "and" "or" and "not"
#
# # 9 What is type casting in Python?
# - Type casting in Python is the process of converting a variable from one data type to another. This can be done either implicitly by Python or explicitly by the programmer.
#
# # 10 What is the difference between implicit and explicit type casting?
# - In implicit type casting, Python automatically converts one data type to another without any user intervention. While in  Explicit type casting user converts  the data type using built-in functions like int(), float(), and str().
#
# # 11 What is the purpose of conditional statements in Python?
# - Conditional statement compares an expression true or false and the flow the control accordingly.
#
# # 12 How does the elif statement work?
# - In Python, the elif keyword is used in conditional statements as an abbreviation for "else if." It allows for additional conditions to be checked if the previous conditions were not met.
#
# # 13 What is the difference between for and while loops?
# - A for loop is typically used when the number of iterations is known in advance. It iterates over a sequence (like a list, tuple, or range) and executes the block of code for each item in the sequence. On the other hand, a while loop is used when the number of iterations is not known beforehand. It continues to execute as long as a specified condition remains true.
#
# # 14 Describe a scenario where a while loop is more suitable than a for loop.
# - Print number from 1 to 10 for loop be used. Say hello while user inputs "Y", while loop is used.

# %% [markdown]
# # Practical Questions .

# %% [markdown]
# # 1. Write a Python program to print "Hello, World!

# %%
print ("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # 2.	Write a Python program that displays your name and age

# %%
my_name = " Manoj Kunwar"
mmyage = 51
print("\n My name is : ")
print(my_name )
print("\n My age is : ")
print(my_age)

# %% [markdown]
# # 3.	Write code to print all the pre-defined keywords in Python using the keyword library

# %%
# Python program to print the list of all keywords

# importing the module
import keyword

# printing the keywords
print("Python keywords are...")
print(keyword.kwlist)

# %% [markdown]
# # 4.	Write a program that checks if a given word is a Python keyword.

# %%
import keyword

# Input from the user
word = input("Enter a word to check if it's a Python keyword: ")

# Check if the word is a keyword
if keyword.iskeyword(word):
    print("This is a Python keyword.")
else:
    print("This is NOT a Python keyword.")

# %% [markdown]
# # 5.	Write a function to demonstrate the behavior of mutable and immutable arguments.

# %%
# Function to demonstrate mutable and immutable behavior
def demonstrate_mutable_and_immutable():
    # Immutable argument example
    def modify_immutable(arg):
        print(f"Before modification (immutable): {arg}")
        arg += 10  # This creates a new object, doesn't modify the original
        print(f"After modification (immutable): {arg}")

    # Mutable argument example
    def modify_mutable(arg):
        print(f"Before modification (mutable): {arg}")
        arg.append(10)  # This modifies the original object
        print(f"After modification (mutable): {arg}")

    # Immutable example
    num = 5
    print("Immutable Example:")
    modify_immutable(num)
    print(f"Outside function (immutable): {num}\n")  # Original remains unchanged
    # Mutable example
    my_list = [1, 2, 3]
    print("Mutable Example:")
    modify_mutable(my_list)
    print(f"Outside function (mutable): {my_list}")  # Original is modified

# Call the function to see the behavior
demonstrate_mutable_and_immutable()
# Out:
# Immutable Example:
# Before modification (immutable): 5
# After modification (immutable): 15
# Outside function (immutable): 5
#
# Mutable Example:
# Before modification (mutable): [1, 2, 3]
# After modification (mutable): [1, 2, 3, 10]
# Outside function (mutable): [1, 2, 3, 10]

# %% [markdown]
# # 6.	Write a program that performs basic arithmetic operations on two user-input numbers.

# %%
# Program to perform basic arithmetic operations

# Taking input from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

# Performing arithmetic operations
addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2 if num2 != 0 else "Undefined (division by zero)"
modulus = num1 % num2 if num2 != 0 else "Undefined (modulus by zero)"
exponentiation = num1 ** num2

# Displaying the results
print("\nResults of Arithmetic Operations:")
print(f"Addition: {addition}")
print(f"Subtraction: {subtraction}")
print(f"Multiplication: {multiplication}")
print(f"Division: {division}")
print(f"Modulus: {modulus}")
print(f"Exponentiation: {exponentiation}")
# Out:
# Enter the first number: Manoj
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-0e5d525f3fe9> in <cell line: 0>()
#       2
#       3 # Taking input from the user
# ----> 4 num1 = float(input("Enter the first number: "))
#       5 num2 = float(input("Enter the second number: "))
#       6
#
# ValueError: could not convert string to float: 'Manoj '

# %% [markdown]
# # 7.	Write a program to demonstrate the use of logical operators.

# %%
# Demonstrating the use of logical operators

# Input values
a = int(input("Enter the first number (a): "))
b = int(input("Enter the second number (b): "))

# Logical AND
if a > 0 and b > 0:
    print("Both a and b are positive numbers.")
else:
    print("At least one of a or b is not positive.")

# Logical OR
if a % 2 == 0 or b % 2 == 0:
    print("At least one of a or b is an even number.")
else:
    print("Both a and b are odd numbers.")

# Logical NOT
if not (a == b):
   print("a and b are not equal.")
else:
   print("a and b are equal.")

# %% [markdown]
# # 8.	Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each.

# %%
# Creating a list and a tuple
my_list = [10, 20, 30]
my_tuple = (10, 20, 30)

# Modifying an element in the list
my_list[1] = 99  # This works because lists are mutable
print("Modified List:", my_list)

# Attempting to modify an element in the tuple
try:
    my_tuple[1] = 99  # This will raise an error because tuples are immutable
except TypeError as e:
        print("Error when modifying tuple:", e)

# %% [markdown]
# # 09 9.	Write a Python program to convert user input from string to integer, float, and boolean types.

# %%
# Get user input as a string
user_input = input("Enter a value: ")

# Convert to integer
try:
    int_value = int(user_input)
    print(f"Integer value: {int_value}")
except ValueError:
            print("Cannot convert to integer.")

# Convert to float
try:
    float_value = float(user_input)
    print(f"Float value: {float_value}")
except ValueError:
    print("Cannot convert to float.")

# Convert to boolean
# Any non-empty string except "0" (or "False") is considered True
bool_value = user_input.lower() not in ["", "0", "false"]
print(f"Boolean value: {bool_value}")

# %% [markdown]
# # 10.	Write code to demonstrate type casting with list elements.

# %%
# Original list with string elements
string_list = ["10", "20", "30", "40.5", "50.7"]

# Type casting string elements to integers (where possible)
int_list = [int(float(item)) for item in string_list]
print("List after casting to integers:", int_list)

# Type casting string elements to floats
float_list = [float(item) for item in string_list]
print("List after casting to floats:", float_list)

# Type casting integers to strings
string_again_list = [str(item) for item in int_list]
print("List after casting back to strings:", string_again_list)

# %% [markdown]
# # 11.	Write a program that checks if a number is positive, negative, or zero.

# %%
# Function to check the number and convert to positive
def check_and_convert_number(num):
    if num > 0:
        print(f"The number {num} is positive.")
    elif num < 0:
        print(f"The number {num} is negative. Converting to positive: {abs(num)}")
    else:
        print("The number is zero. Converting to positive: 0")

# Input from the user

try:
   number = float(input("Enter a number: "))
   check_and_convert_number(number)
except ValueError:
                            print("Please enter a valid number.")

# %% [markdown]
# # 12.	Write a for loop to print numbers from 1 to 10.#

# %%
for i in range(1, 11):
      print(i)

# %% [markdown]
# # 13.	Write a Python program to find the sum of all even numbers between 1 and 50.

# %%
# Initialize the sum variable
sum_of_evens = 0

# Loop through numbers from 1 to 50
for number in range(1, 51):
    # Check if the number is even
    if number % 2 == 0:
       sum_of_evens += number

# Print the result
print("The sum of all even numbers between 1 and 50 is:", sum_of_evens)

# %% [markdown]
# # 14.	Write a program to reverse a string using a while loop.

# %%
# Function to reverse a string using a while loop
def reverse_string(input_string):
    reversed_string = ""
    index = len(input_string) - 1  # Start from the last character

    while index >= 0:
          reversed_string += input_string[index]  # Append the character to the result
          index -= 1  # Move to the previous character

    return reversed_string

# Example usage
original_string = "Hello, World!"
reversed_result = reverse_string(original_string)
print("Original String:", original_string)
print("Reversed String:", reversed_result)

# %% [markdown]
# # 15.	Write a Python program to calculate the factorial of a number provided by the user using a while loop.

# %%
# Program to calculate the factorial of a number using a while loop

# Get input from the user
num = int(input("Enter a non-negative integer: "))

# Initialize variables
factorial = 1
i = 1

# Check if the input is valid
if num < 0:
    print("Factorial is not defined for negative numbers.")
else:
    # Calculate factorial using a while loop
    while i <= num:
          factorial *= i
          i += 1

    # Display the result
    print(f"The factorial of {num} is {factorial}.")
